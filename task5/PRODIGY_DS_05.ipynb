# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("US_Accidents_March23.csv")

# %%
df.head(10)
# Out:
#      ID   Source  Severity           Start_Time             End_Time  \
# 0   A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1   A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2   A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3   A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4   A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# 5   A-6  Source2         3  2016-02-08 07:44:26  2016-02-08 08:14:26
# 6   A-7  Source2         2  2016-02-08 07:59:35  2016-02-08 08:29:35
# 7   A-8  Source2         3  2016-02-08 07:59:58  2016-02-08 08:29:58
# 8   A-9  Source2         2  2016-02-08 08:00:40  2016-02-08 08:30:40
# 9  A-10  Source2         3  2016-02-08 08:10:04  2016-02-08 08:40:04
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
# 5  40.100590 -82.925194      NaN      NaN          0.01  ...      False
# 6  39.758274 -84.230507      NaN      NaN          0.00  ...      False
# 7  39.770382 -84.194901      NaN      NaN          0.01  ...      False
# 8  39.778061 -84.172005      NaN      NaN          0.00  ...      False
# 9  40.100590 -82.925194      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False          Night
# 1   False  False           False          False        False          Night
# 2   False  False           False           True        False          Night
# 3   False  False           False          False        False          Night
# 4   False  False           False           True        False            Day
# 5   False  False           False          False        False            Day
# 6   False  False           False          False        False            Day
# 7   False  False           False          False        False            Day
# 8   False  False           False          False        False            Day
# 9   False  False           False          False        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day
# 5            Day               Day                   Day
# 6            Day               Day                   Day
# 7            Day               Day                   Day
# 8            Day               Day                   Day
# 9            Day               Day                   Day
#
# [10 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                        object
# Source                    object
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Street                    object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Precipitation(in)        float64
# Weather_Condition         object
# Amenity                     bool
# Bump                        bool
# Crossing                    bool
# Give_Way                    bool
# Junction                    bool
# No_Exit                     bool
# Railway                     bool
# Roundabout                  bool
# Station                     bool
# Stop                        bool
# Traffic_Calming             bool
# Traffic_Signal              bool
# Turning_Loop                bool
# Sunrise_Sunset            object
# Civil_Twilight            object
# Nautical_Twilight         object
# Astronomical_Twilight     object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     20
# bool       13
# float64    12
# int64       1
# dtype: int64

# %%
df.shape
# Out:
# (7728394, 46)

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# min    0.000000e+00   -8.900000e+01  -8.900000e+01  1.000000e+00
# 25%    0.000000e+00    4.900000e+01   4.300000e+01  4.800000e+01
# 50%    3.000000e-02    6.400000e+01   6.200000e+01  6.700000e+01
# 75%    4.640000e-01    7.600000e+01   7.500000e+01  8.400000e+01
# max    4.417500e+02    2.070000e+02   2.070000e+02  1.000000e+02
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  7.587715e+06    7.551296e+06     7.157161e+06       5.524808e+06
# mean   2.953899e+01    9.090376e+00     7.685490e+00       8.407210e-03
# std    1.006190e+00    2.688316e+00     5.424983e+00       1.102246e-01
# min    0.000000e+00    0.000000e+00     0.000000e+00       0.000000e+00
# 25%    2.937000e+01    1.000000e+01     4.600000e+00       0.000000e+00
# 50%    2.986000e+01    1.000000e+01     7.000000e+00       0.000000e+00
# 75%    3.003000e+01    1.000000e+01     1.040000e+01       0.000000e+00
# max    5.863000e+01    1.400000e+02     1.087000e+03       3.647000e+01

# %%
df.City.unique
# Out:
# <bound method Series.unique of 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 7728389       Riverside
# 7728390       San Diego
# 7728391          Orange
# 7728392     Culver City
# 7728393        Highland
# Name: City, Length: 7728394, dtype: object>

# %%
df.State.unique
# Out:
# <bound method Series.unique of 0          OH
# 1          OH
# 2          OH
# 3          OH
# 4          OH
#            ..
# 7728389    CA
# 7728390    CA
# 7728391    CA
# 7728392    CA
# 7728393    CA
# Name: State, Length: 7728394, dtype: object>

# %%
df1=df[df["State"]=="CA"]

# %%
df1
# Out:
#                 ID   Source  Severity           Start_Time  \
# 728          A-729  Source2         3  2016-06-21 10:34:40
# 729          A-730  Source2         3  2016-06-21 10:30:16
# 730          A-731  Source2         2  2016-06-21 10:49:14
# 731          A-732  Source2         3  2016-06-21 10:41:42
# 732          A-733  Source2         2  2016-06-21 10:16:26
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 728      2016-06-21 11:04:40  38.085300 -122.233017       NaN        NaN
# 729      2016-06-21 11:16:39  37.631813 -122.084167       NaN        NaN
# 730      2016-06-21 11:19:14  37.896564 -122.070717       NaN        NaN
# 731      2016-06-21 11:11:42  37.334255 -122.032471       NaN        NaN
# 732      2016-06-21 11:04:16  37.250729 -121.910713       NaN        NaN
# ...                      ...        ...         ...       ...        ...
# 7728389  2019-08-23 18:32:01  34.002480 -117.379360  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23  32.766960 -117.148060  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49  33.775450 -117.847790  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42  33.992460 -118.403020  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31  34.133930 -117.230920  34.13736 -117.23934
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 728             0.000  ...      False   False  False           False
# 729             0.000  ...      False   False  False           False
# 730             0.000  ...      False   False  False           False
# 731             0.000  ...      False   False  False           False
# 732             0.000  ...      False   False  False           False
# ...               ...  ...        ...     ...    ...             ...
# 7728389         0.543  ...      False   False  False           False
# 7728390         0.338  ...      False   False  False           False
# 7728391         0.561  ...      False   False  False           False
# 7728392         0.772  ...      False   False  False           False
# 7728393         0.537  ...      False   False  False           False
#
#         Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 728              False        False            Day            Day
# 729              False        False            Day            Day
# 730              False        False            Day            Day
# 731              False        False            Day            Day
# 732              False        False            Day            Day
# ...                ...          ...            ...            ...
# 7728389          False        False            Day            Day
# 7728390          False        False            Day            Day
# 7728391          False        False            Day            Day
# 7728392          False        False            Day            Day
# 7728393          False        False            Day            Day
#
#         Nautical_Twilight Astronomical_Twilight
# 728                   Day                   Day
# 729                   Day                   Day
# 730                   Day                   Day
# 731                   Day                   Day
# 732                   Day                   Day
# ...                   ...                   ...
# 7728389               Day                   Day
# 7728390               Day                   Day
# 7728391               Day                   Day
# 7728392               Day                   Day
# 7728393               Day                   Day
#
# [1741433 rows x 46 columns]

# %%
df["State"].unique()
# Out:
# array(['OH', 'WV', 'CA', 'FL', 'GA', 'SC', 'NE', 'IA', 'IL', 'MO', 'WI',
#        'IN', 'MI', 'NJ', 'NY', 'CT', 'MA', 'RI', 'NH', 'PA', 'KY', 'MD',
#        'VA', 'DC', 'DE', 'TX', 'WA', 'OR', 'AL', 'NC', 'AZ', 'TN', 'LA',
#        'MN', 'CO', 'OK', 'NV', 'UT', 'KS', 'NM', 'AR', 'MS', 'ME', 'VT',
#        'WY', 'ID', 'ND', 'MT', 'SD'], dtype=object)

# %%
df1['IDD'] = df1['ID'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
# Out:
# C:\Users\indro\AppData\Local\Temp/ipykernel_6412/1955134751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['IDD'] = df1['ID'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

# %%
df1
# Out:
#                 ID   Source  Severity           Start_Time  \
# 728          A-729  Source2         3  2016-06-21 10:34:40
# 729          A-730  Source2         3  2016-06-21 10:30:16
# 730          A-731  Source2         2  2016-06-21 10:49:14
# 731          A-732  Source2         3  2016-06-21 10:41:42
# 732          A-733  Source2         2  2016-06-21 10:16:26
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 728      2016-06-21 11:04:40  38.085300 -122.233017       NaN        NaN
# 729      2016-06-21 11:16:39  37.631813 -122.084167       NaN        NaN
# 730      2016-06-21 11:19:14  37.896564 -122.070717       NaN        NaN
# 731      2016-06-21 11:11:42  37.334255 -122.032471       NaN        NaN
# 732      2016-06-21 11:04:16  37.250729 -121.910713       NaN        NaN
# ...                      ...        ...         ...       ...        ...
# 7728389  2019-08-23 18:32:01  34.002480 -117.379360  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23  32.766960 -117.148060  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49  33.775450 -117.847790  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42  33.992460 -118.403020  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31  34.133930 -117.230920  34.13736 -117.23934
#
#          Distance(mi)  ... Station   Stop Traffic_Calming Traffic_Signal  \
# 728             0.000  ...   False  False           False          False
# 729             0.000  ...   False  False           False          False
# 730             0.000  ...   False  False           False          False
# 731             0.000  ...   False  False           False          False
# 732             0.000  ...   False  False           False          False
# ...               ...  ...     ...    ...             ...            ...
# 7728389         0.543  ...   False  False           False          False
# 7728390         0.338  ...   False  False           False          False
# 7728391         0.561  ...   False  False           False          False
# 7728392         0.772  ...   False  False           False          False
# 7728393         0.537  ...   False  False           False          False
#
#         Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 728            False            Day            Day               Day
# 729            False            Day            Day               Day
# 730            False            Day            Day               Day
# 731            False            Day            Day               Day
# 732            False            Day            Day               Day
# ...              ...            ...            ...               ...
# 7728389        False            Day            Day               Day
# 7728390        False            Day            Day               Day
# 7728391        False            Day            Day               Day
# 7728392        False            Day            Day               Day
# 7728393        False            Day            Day               Day
#
#         Astronomical_Twilight      IDD
# 728                       Day      729
# 729                       Day      730
# 730                       Day      731
# 731                       Day      732
# 732                       Day      733
# ...                       ...      ...
# 7728389                   Day  7777757
# 7728390                   Day  7777758
# 7728391                   Day  7777759
# 7728392                   Day  7777760
# 7728393                   Day  7777761
#
# [1741433 rows x 47 columns]

# %%
df1.head()
# Out:
#         ID   Source  Severity           Start_Time             End_Time  \
# 728  A-729  Source2         3  2016-06-21 10:34:40  2016-06-21 11:04:40
# 729  A-730  Source2         3  2016-06-21 10:30:16  2016-06-21 11:16:39
# 730  A-731  Source2         2  2016-06-21 10:49:14  2016-06-21 11:19:14
# 731  A-732  Source2         3  2016-06-21 10:41:42  2016-06-21 11:11:42
# 732  A-733  Source2         2  2016-06-21 10:16:26  2016-06-21 11:04:16
#
#      Start_Lat   Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Station  \
# 728  38.085300 -122.233017      NaN      NaN           0.0  ...   False
# 729  37.631813 -122.084167      NaN      NaN           0.0  ...   False
# 730  37.896564 -122.070717      NaN      NaN           0.0  ...   False
# 731  37.334255 -122.032471      NaN      NaN           0.0  ...   False
# 732  37.250729 -121.910713      NaN      NaN           0.0  ...   False
#
#       Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 728  False           False          False        False            Day
# 729  False           False          False        False            Day
# 730  False           False          False        False            Day
# 731  False           False          False        False            Day
# 732  False           False          False        False            Day
#
#     Civil_Twilight Nautical_Twilight Astronomical_Twilight  IDD
# 728            Day               Day                   Day  729
# 729            Day               Day                   Day  730
# 730            Day               Day                   Day  731
# 731            Day               Day                   Day  732
# 732            Day               Day                   Day  733
#
# [5 rows x 47 columns]

# %%
df1.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'IDD'],
#       dtype='object')

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.shape
# Out:
# (1741433, 47)

# %%
df1=df1.dropna(subset=['Temperature(F)','Wind_Chill(F)','Humidity(%)','Pressure(in)','Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)','Weather_Condition'])

# %%
df1.shape
# Out:
# (1223324, 47)

# %%
df1
# Out:
#                 ID   Source  Severity           Start_Time  \
# 5041        A-5042  Source2         2  2016-11-30 16:07:48
# 5063        A-5064  Source2         2  2016-11-30 18:32:56
# 5073        A-5074  Source2         2  2016-11-30 19:20:50
# 5075        A-5076  Source2         2  2016-11-30 19:33:50
# 5080        A-5081  Source2         2  2016-11-30 19:40:52
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 5041     2016-11-30 17:22:27  38.660347 -120.980392       NaN        NaN
# 5063     2016-11-30 19:17:31  38.675434 -120.881569       NaN        NaN
# 5073     2016-11-30 20:05:34  38.596119 -121.412254       NaN        NaN
# 5075     2016-11-30 20:18:18  38.692959 -121.351631       NaN        NaN
# 5080     2016-11-30 20:25:35  38.359741 -120.821121       NaN        NaN
# ...                      ...        ...         ...       ...        ...
# 7728389  2019-08-23 18:32:01  34.002480 -117.379360  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23  32.766960 -117.148060  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49  33.775450 -117.847790  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42  33.992460 -118.403020  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31  34.133930 -117.230920  34.13736 -117.23934
#
#          Distance(mi)  ... Station   Stop Traffic_Calming Traffic_Signal  \
# 5041            0.010  ...   False  False           False          False
# 5063            0.010  ...   False  False           False          False
# 5073            0.010  ...   False  False           False          False
# 5075            0.010  ...   False  False           False           True
# 5080            0.010  ...   False  False           False           True
# ...               ...  ...     ...    ...             ...            ...
# 7728389         0.543  ...   False  False           False          False
# 7728390         0.338  ...   False  False           False          False
# 7728391         0.561  ...   False  False           False          False
# 7728392         0.772  ...   False  False           False          False
# 7728393         0.537  ...   False  False           False          False
#
#         Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 5041           False            Day            Day               Day
# 5063           False          Night          Night             Night
# 5073           False          Night          Night             Night
# 5075           False          Night          Night             Night
# 5080           False          Night          Night             Night
# ...              ...            ...            ...               ...
# 7728389        False            Day            Day               Day
# 7728390        False            Day            Day               Day
# 7728391        False            Day            Day               Day
# 7728392        False            Day            Day               Day
# 7728393        False            Day            Day               Day
#
#         Astronomical_Twilight      IDD
# 5041                      Day     5042
# 5063                    Night     5064
# 5073                    Night     5074
# 5075                    Night     5076
# 5080                    Night     5081
# ...                       ...      ...
# 7728389                   Day  7777757
# 7728390                   Day  7777758
# 7728391                   Day  7777759
# 7728392                   Day  7777760
# 7728393                   Day  7777761
#
# [1223324 rows x 47 columns]

# %%
df1.isna().sum()/len(df1)*100
# Out:
# ID                        0.000000
# Source                    0.000000
# Severity                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# End_Lat                  22.135591
# End_Lng                  22.135591
# Distance(mi)              0.000000
# Description               0.000163
# Street                    0.192835
# City                      0.000572
# County                    0.000000
# State                     0.000000
# Zipcode                   0.000000
# Country                   0.000000
# Timezone                  0.000000
# Airport_Code              0.000000
# Weather_Timestamp         0.000000
# Temperature(F)            0.000000
# Wind_Chill(F)             0.000000
# Humidity(%)               0.000000
# Pressure(in)              0.000000
# Visibility(mi)            0.000000
# Wind_Direction            0.000000
# Wind_Speed(mph)           0.000000
# Precipitation(in)         8.197583
# Weather_Condition         0.000000
# Amenity                   0.000000
# Bump                      0.000000
# Crossing                  0.000000
# Give_Way                  0.000000
# Junction                  0.000000
# No_Exit                   0.000000
# Railway                   0.000000
# Roundabout                0.000000
# Station                   0.000000
# Stop                      0.000000
# Traffic_Calming           0.000000
# Traffic_Signal            0.000000
# Turning_Loop              0.000000
# Sunrise_Sunset            0.061635
# Civil_Twilight            0.061635
# Nautical_Twilight         0.061635
# Astronomical_Twilight     0.061635
# IDD                       0.000000
# dtype: float64

# %%
df1=df1.dropna(subset=['City','Sunrise_Sunset',
       'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight'])

# %%
df1.isna().sum()/len(df1)*100
# Out:
# ID                        0.000000
# Source                    0.000000
# Severity                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# End_Lat                  22.144499
# End_Lng                  22.144499
# Distance(mi)              0.000000
# Description               0.000164
# Street                    0.192463
# City                      0.000000
# County                    0.000000
# State                     0.000000
# Zipcode                   0.000000
# Country                   0.000000
# Timezone                  0.000000
# Airport_Code              0.000000
# Weather_Timestamp         0.000000
# Temperature(F)            0.000000
# Wind_Chill(F)             0.000000
# Humidity(%)               0.000000
# Pressure(in)              0.000000
# Visibility(mi)            0.000000
# Wind_Direction            0.000000
# Wind_Speed(mph)           0.000000
# Precipitation(in)         8.202066
# Weather_Condition         0.000000
# Amenity                   0.000000
# Bump                      0.000000
# Crossing                  0.000000
# Give_Way                  0.000000
# Junction                  0.000000
# No_Exit                   0.000000
# Railway                   0.000000
# Roundabout                0.000000
# Station                   0.000000
# Stop                      0.000000
# Traffic_Calming           0.000000
# Traffic_Signal            0.000000
# Turning_Loop              0.000000
# Sunrise_Sunset            0.000000
# Civil_Twilight            0.000000
# Nautical_Twilight         0.000000
# Astronomical_Twilight     0.000000
# IDD                       0.000000
# dtype: float64

# %%
df1['Weather_Condition'].value_counts()
# Out:
# Fair                       757055
# Cloudy                     136294
# Mostly Cloudy               97801
# Partly Cloudy               78075
# Light Rain                  37422
#                             ...
# Light Snow Showers              1
# Rain Showers                    1
# Light Snow with Thunder         1
# Sand / Windy                    1
# Blowing Sand                    1
# Name: Weather_Condition, Length: 76, dtype: int64

# %%
df_cat=df1.select_dtypes('object')
df_num=df1.select_dtypes(np.number)
df_cat=df_cat.drop('ID',axis=1)

# %%
df_cat=df1.select_dtypes('object')
col_name=[]
length=[]

for i in df_cat.columns:
    col_name.append(i)
    length.append(len(df_cat[i].unique()))
df_2=pd.DataFrame(zip(col_name,length),columns=['feature','count_of_unique_values'])
df_2
# Out:
#                   feature  count_of_unique_values
# 0                      ID                 1222570
# 1                  Source                       3
# 2              Start_Time                  919564
# 3                End_Time                 1074784
# 4             Description                  579784
# 5                  Street                   58486
# 6                    City                    1099
# 7                  County                      58
# 8                   State                       1
# 9                 Zipcode                  109898
# 10                Country                       1
# 11               Timezone                       2
# 12           Airport_Code                     135
# 13      Weather_Timestamp                  272950
# 14         Wind_Direction                      23
# 15      Weather_Condition                      76
# 16         Sunrise_Sunset                       2
# 17         Civil_Twilight                       2
# 18      Nautical_Twilight                       2
# 19  Astronomical_Twilight                       2

# %%
df1.drop(['Description','Zipcode','Weather_Timestamp'],axis=1,inplace=True)
# Out:
# C:\Users\indro\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
del df1['Airport_Code']

# %%
df_num.columns
# Out:
# Index(['Severity', 'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng',
#        'Distance(mi)', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'IDD'],
#       dtype='object')

# %%
len(df_num.columns)
# Out:
# 14

# %%
df_cat.columns
# Out:
# Index(['ID', 'Source', 'Start_Time', 'End_Time', 'Description', 'Street',
#        'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Wind_Direction',
#        'Weather_Condition', 'Sunrise_Sunset', 'Civil_Twilight',
#        'Nautical_Twilight', 'Astronomical_Twilight'],
#       dtype='object')

# %%
df_num=df1.select_dtypes(np.number)
col_name=[]
length=[]

for i in df_num.columns:
    col_name.append(i)
    length.append(len(df_num[i].unique()))
df_2=pd.DataFrame(zip(col_name,length),columns=['feature','count_of_unique_values'])
df_2
# Out:
#               feature  count_of_unique_values
# 0            Severity                       4
# 1           Start_Lat                  396157
# 2           Start_Lng                  401200
# 3             End_Lat                  313577
# 4             End_Lng                  318210
# 5        Distance(mi)                   12929
# 6      Temperature(F)                     221
# 7       Wind_Chill(F)                     397
# 8         Humidity(%)                     100
# 9        Pressure(in)                     820
# 10     Visibility(mi)                      47
# 11    Wind_Speed(mph)                      96
# 12  Precipitation(in)                      88
# 13                IDD                 1222570

# %%
plt.figure(figsize=(15 ,9))
sns.heatmap(df_num.corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
cities=df1["City"].unique()
len(cities)
# Out:
# 1099

# %%
accidents_by_cities = df1['City'].value_counts()
accidents_by_cities
# Out:
# Los Angeles           104141
# Sacramento             48339
# San Diego              39373
# San Jose               21581
# Bakersfield            19109
#                        ...
# La Mesa                    1
# Desert Center              1
# Desert Hot Springs         1
# Warner Springs             1
# Canyon Lake                1
# Name: City, Length: 1099, dtype: int64

# %%
#top 10 cities by number of accident
accidents_by_cities[:10]
# Out:
# Los Angeles       104141
# Sacramento         48339
# San Diego          39373
# San Jose           21581
# Bakersfield        19109
# Riverside          18845
# San Bernardino     16544
# Oakland            15236
# Fresno             14981
# Anaheim            14553
# Name: City, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,5))
accidents_by_cities[:10].plot(kind='bar')
ax.set(title = 'Top 10 cities By Number of Accidents',
       xlabel = 'Cities',
       ylabel = 'Accidents Count')
plt.show()

# %%
accidents_severity = df1.groupby('Severity').count()['ID']
fig, ax = plt.subplots(figsize=(8, 6), subplot_kw=dict(aspect="equal"))
label = [1,2,3,4]
plt.pie(accidents_severity, labels=label,
        autopct='%1.1f%%', pctdistance=0.85)
circle = plt.Circle( (0,0), 0.5, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
ax.set_title("Accident by Severity",fontdict={'fontsize': 16})
plt.tight_layout()
plt.show()

# %%
df1["Start_Time"].dtypes
# Out:
# dtype('O')

# %%
df1["End_Time"].dtypes
# Out:
# dtype('O')

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.histplot(df1['Start_Time'].dt.hour, bins = 24,color="Red")

plt.xlabel("Start Time")
plt.ylabel("Number of Occurence")
plt.title('Accidents Count By Time of Day')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.histplot(df1['Start_Time'].dt.hour, bins = 24,color="Green")

plt.xlabel("End_Time")
plt.ylabel("Number of Occurence")
plt.title('Accidents Count By Time of Day')

plt.show()

# %%
sns.jointplot(x=df_num.Start_Lat.values , y=df_num.Start_Lng.values,height=10,color="Purple")
plt.ylabel('Start lattitude', fontsize=12)
plt.xlabel('Start lattitude', fontsize=12)
plt.show()

# %%
sns.jointplot(x=df_num.End_Lat.values , y=df_num.End_Lng.values,height=10)
plt.ylabel('end lattitude', fontsize=12)
plt.xlabel('end longitude', fontsize=12)
plt.show()
